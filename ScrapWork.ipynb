# %%
import os 
import pandas as pd

# %%
sshell_dir = 'data/subject_shells'

# %%
os.listdir(sshell_dir)
# Out:
# ['S0101.xlsx',
#  'S0601.xlsx',
#  'S0801.xlsx',
#  'S0802.xlsx',
#  'S1101.xlsx',
#  'S1201.xlsx',
#  'S1501.xlsx',
#  'S1601.xlsx',
#  'S1903.xlsx',
#  'S2403.xlsx',
#  'S2501.xlsx',
#  'S2502.xlsx',
#  'S2801.xlsx']

# %%
S0101_shell = pd.read_excel(os.path.join(sshell_dir, 'S0101.xlsx'))

# %%
S0101_shell.head()
# Out:
#   Table ID  Line Number        Description Unnamed: 3        Unnamed: 4  \
# 0   S0101           0.0       AGE AND SEX         NaN               NaN
# 1   S0101           0.5           Subject      Total   Margin of Error
# 2   S0101           1.0  Total population          #
# 3   S0101           1.5               AGE
# 4   S0101           2.0     Under 5 years          #
#
#   Unnamed: 5        Unnamed: 6 Unnamed: 7        Unnamed: 8     Unnamed: 9  \
# 0        NaN               NaN        NaN               NaN            NaN
# 1   Percent   Margin of Error       Male   Margin of Error   Percent Male
# 2       (X)                            #                              (X)
# 3
# 4         %                            #                                %
#
#         Unnamed: 10 Unnamed: 11       Unnamed: 12      Unnamed: 13  \
# 0
# 1  Margin of Error      Female   Margin of Error   Percent Female
# 2                            #                                (X)
# 3
# ...

# %%
st_dir = 'data/subject_tables/unzipped_files'

# %%
[f for f in os.listdir(st_dir) if 'S0101' in f]
# Out:
# ['ACSST5Y2019.S0101_2021-01-12T120250']

# %%
current_target = os.path.join(st_dir, 'ACSST5Y2019.S0101_2021-01-12T120250')

# %%
os.listdir(current_target)
# Out:
# ['ACSST5Y2019.S0101_data_with_overlays_2021-01-08T174020.csv',
#  'ACSST5Y2019.S0101_metadata_2021-01-08T174020.csv',
#  'ACSST5Y2019.S0101_table_title_2021-01-08T174020.txt']

# %%
S0101_data = pd.read_csv(current_target + '/ACSST5Y2019.S0101_data_with_overlays_2021-01-08T174020.csv', low_memory=False)

# %%
S0101_data.shape
# Out:
# (5266, 458)

# %%
S0101_data.head()
# Out:
#                  GEO_ID                                          NAME  \
# 0                    id                          Geographic Area Name
# 1  1400000US48001950100     Census Tract 9501, Anderson County, Texas
# 2  1400000US48001950401  Census Tract 9504.01, Anderson County, Texas
# 3  1400000US48001950402  Census Tract 9504.02, Anderson County, Texas
# 4  1400000US48001950500     Census Tract 9505, Anderson County, Texas
#
#                       S0101_C01_001E  \
# 0  Estimate!!Total!!Total population
# 1                               4844
# 2                               4838
# 3                               7511
# 4                               4465
#
#                              S0101_C01_001M  \
# 0  Margin of Error!!Total!!Total population
# 1                                       524
# 2                                       235
# 3                                       398
# 4                                       495
#
# ...

# %%
S0101_meta.head()
# Out:
#            GEO_ID                                                 id
# 0            NAME                               Geographic Area Name
# 1  S0101_C01_001E                  Estimate!!Total!!Total population
# 2  S0101_C01_001M           Margin of Error!!Total!!Total population
# 3  S0101_C01_002E  Estimate!!Total!!Total population!!AGE!!Under ...
# 4  S0101_C01_002M  Margin of Error!!Total!!Total population!!AGE!...

# %%
S0101_meta = pd.read_csv(current_target + '/ACSST5Y2019.S0101_metadata_2021-01-08T174020.csv')

# %%
S0101_meta.head()
# Out:
#            GEO_ID                                                 id
# 0            NAME                               Geographic Area Name
# 1  S0101_C01_001E                  Estimate!!Total!!Total population
# 2  S0101_C01_001M           Margin of Error!!Total!!Total population
# 3  S0101_C01_002E  Estimate!!Total!!Total population!!AGE!!Under ...
# 4  S0101_C01_002M  Margin of Error!!Total!!Total population!!AGE!...

# %%
S0101_shell.head()
# Out:
#   Table ID  Line Number        Description Unnamed: 3        Unnamed: 4  \
# 0   S0101           0.0       AGE AND SEX         NaN               NaN
# 1   S0101           0.5           Subject      Total   Margin of Error
# 2   S0101           1.0  Total population          #
# 3   S0101           1.5               AGE
# 4   S0101           2.0     Under 5 years          #
#
#   Unnamed: 5        Unnamed: 6 Unnamed: 7        Unnamed: 8     Unnamed: 9  \
# 0        NaN               NaN        NaN               NaN            NaN
# 1   Percent   Margin of Error       Male   Margin of Error   Percent Male
# 2       (X)                            #                              (X)
# 3
# 4         %                            #                                %
#
#         Unnamed: 10 Unnamed: 11       Unnamed: 12      Unnamed: 13  \
# 0
# 1  Margin of Error      Female   Margin of Error   Percent Female
# 2                            #                                (X)
# 3
# ...

# %%
refined = S0101_shell[S0101_shell['Line Number'].apply(lambda x: x.is_integer())].copy()

# %%
refined
# Out:
#    Table ID  Line Number                         Description Unnamed: 3  \
# 0    S0101             0                        AGE AND SEX         NaN
# 2    S0101             1                   Total population          #
# 4    S0101             2                      Under 5 years          #
# 5    S0101             3                       5 to 9 years          #
# 6    S0101             4                     10 to 14 years          #
# 7    S0101             5                     15 to 19 years          #
# 8    S0101             6                     20 to 24 years          #
# 9    S0101             7                     25 to 29 years          #
# 10   S0101             8                     30 to 34 years          #
# 11   S0101             9                     35 to 39 years          #
# 12   S0101            10                     40 to 44 years          #
# 13   S0101            11                     45 to 49 years          #
# ...
